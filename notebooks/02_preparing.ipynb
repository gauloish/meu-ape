# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_parquet("../data/processed/01_cleaned.parquet")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9833 entries, 0 to 9838
# Data columns (total 41 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  9833 non-null   object
#  1   preco               9833 non-null   Int64
#  2   condominio          7712 non-null   Int64
#  3   iptu                5880 non-null   Int64
#  4   endereco            9833 non-null   object
#  5   tamanho             9833 non-null   Int64
#  6   quartos             9831 non-null   Int64
#  7   banheiros           9831 non-null   Int64
#  8   vagas               9567 non-null   Int64
#  9   andar               4494 non-null   Int64
#  10  descricao           9833 non-null   object
#  11  piscina             9833 non-null   boolean
#  12  elevador            9833 non-null   boolean
#  13  condominio_fechado  9833 non-null   boolean
#  14  academia            9833 non-null   boolean
#  15  espaco_gourmet      9833 non-null   boolean
# ...

# %%
print(df.head(10).to_string())
# Out:
#                                             id   preco  condominio  iptu                                                         endereco  tamanho  quartos  banheiros  vagas  andar                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  
# ...
